# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.head())
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
print(df.shape)#get the number rows and columns
print(df.shape[0])#get the number of rows only
print(df.shape[1])#get the number of columns only
# Out:
# (17, 7)
# 17
# 7

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
print(df['SEM1'])
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
print(df2[['SEM1','Names']])
print(df[df.index==1])
print(df[df.index.isin(range(2,5))])
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    NaN  Kissan
# 3    NaN    Mary
# 4    NaN    Jeen
# 5    NaN     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
print(df2.loc[3])
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
# Names       Mary
# Initials       N
# SEM1         NaN
# SEM2         8.0
# SEM3         NaN
# Grade          B
# Placed         0
# Name: 3, dtype: object

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
print(df2.loc[6:8]==0)
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 6  False     False  False  False  False  False   False
# 7  False     False  False  False  False  False   False
# 8  False     False  False  False  False  False   False

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
df2.loc[[10,2,7]]
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 7     Mari        N   7.7   8.0   7.1     B       1

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
print(df2.isnull().sum())
df2.iloc[10:14, :3]#[row,column]
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df2.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df2[df.Grade=='A']
df2[df.SEM2==10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df.loc[df['SEM1']>9.8,['Names']]#printing names of s
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df3=df2.copy()
#df3=df3.dropna()
df3

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df3=df2.copy()
df3.dropna(inplace=True, axis=1)
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df3=df2.copy()
df3.dropna(inplace=True, how='all')
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df3=df2.copy()
mv=df3['SEM1'].mean()
df3=df3.fillna(9.8)
print(df3)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.8   9.8  10.0     A       0
# 3     Mary        N   9.8   8.0   9.8     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   9.8   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.8   9.1   9.9    A+       1
# 9   Rajini        M   9.8   9.1   9.3     A       0
# 10   Kiran        V   9.8   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
df2.isnull().sum()
df3=df2.copy()
mv=df3['SEM1'].mean()
df3=df3.fillna(mv)
print(df3)
